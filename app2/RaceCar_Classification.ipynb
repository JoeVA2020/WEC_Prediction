# %%
# importing required Pakages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Converting csv to Dataframe

df=pd.read_csv('2012-2022_FIA_WEC_LAP_DATA.csv')
df
# Out:
# C:\Users\joeva\AppData\Local\Temp\ipykernel_24924\1351903942.py:3: DtypeWarning: Columns (26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('2012-2022_FIA_WEC_LAP_DATA.csv')
#         Unnamed: 0  number  driver_number  lap_number                lap_time  \
# 0                0      57              1           1  0 days 00:02:23.141000
# 1                1      88              2           1  0 days 00:02:24.016000
# 2                2      50              2           1  0 days 00:02:25.278000
# 3                3      70              2           1  0 days 00:02:25.548000
# 4                4      61              2           1  0 days 00:02:25.859000
# ...            ...     ...            ...         ...                     ...
# 503675      503675       7              3         378  0 days 00:03:32.801000
# 503676      503676       8              2         379  0 days 00:03:32.310000
# 503677      503677       7              3         379  0 days 00:03:33.348000
# 503678      503678       8              2         380  0 days 00:03:36.142000
# 503679      503679       7              3         380  0 days 00:03:35.207000
#
#         lap_improvement crossing_finish_line_in_pit      s1  s1_improvement  \
# 0                     0                         NaN  52.533               0
# 1                     0                         NaN  52.915               0
# 2                     0                         NaN  53.568               0
# 3                     0                         NaN  53.938               0
# 4                     0                         NaN  54.482               0
# ...                 ...                         ...     ...             ...
# 503675                0                         NaN  33.645               0
# 503676                0                         NaN  33.323               0
# 503677                0                         NaN  34.550               0
# 503678                0                         NaN  33.452               0
# 503679                0                         NaN  33.411               0
#
#             s2  ...                           team_stint  elapsed_ms  \
# 0       45.335  ...            Krohn Racing #57 Stint #1      143141
# 1       45.342  ...  Team Felbermayr-Proton #88 Stint #1      144016
# 2       45.577  ...      Larbre Competition #50 Stint #1      145278
# 3       45.614  ...      Larbre Competition #70 Stint #1      145548
# 4       45.816  ...        AF Corse-Waltrip #61 Stint #1      145859
# ...        ...  ...                                  ...         ...
# 503675  80.892  ...     Toyota Gazoo Racing #7 Stint #33    86220663
# 503676  80.052  ...     Toyota Gazoo Racing #8 Stint #32    86311854
# 503677  81.034  ...     Toyota Gazoo Racing #7 Stint #33    86434011
# 503678  80.406  ...     Toyota Gazoo Racing #8 Stint #32    86527996
# 503679  80.843  ...     Toyota Gazoo Racing #7 Stint #33    86649218
#
#         position  class_position interval_ms interval      gap class_interval  \
# 0           20.0             1.0       349.0    0.349   26.922          0.000
# 1           21.0             2.0       875.0    0.875   27.797          0.875
# 2           22.0             3.0      1262.0    1.262   29.059          1.262
# 3           23.0             4.0       270.0    0.270   29.329          0.270
# 4           24.0             5.0       311.0    0.311   29.640          0.311
# ...          ...             ...         ...      ...      ...            ...
# 503675       2.0             2.0    121119.0  121.119  212.801        121.119
# 503676       1.0             1.0     91191.0   91.191   91.191          0.000
# 503677       2.0             2.0    122157.0  122.157  213.348        122.157
# 503678       1.0             1.0     93985.0   93.985   93.985          0.000
# 503679       2.0             2.0    121222.0  121.222  215.207        121.222
#
#        class_gap  elapsed_s
# 0          0.000    143.141
# 1          0.875    144.016
# 2          2.137    145.278
# 3          2.407    145.548
# 4          2.718    145.859
# ...          ...        ...
# 503675   121.119  86220.663
# 503676     0.000  86311.854
# 503677   122.157  86434.011
# 503678     0.000  86527.996
# 503679   121.222  86649.218
#
# [503680 rows x 48 columns]

# %%
df['class'].value_counts()
# Out:
# class
# LMP2              168680
# LMGTE Am          131889
# LMGTE Pro         101579
# LMP1               79703
# LMP1-H              9978
# HYPERCAR            8512
# LMP1-L              2610
# CDNT                 395
# INNOVATIVE CAR       334
# Name: count, dtype: int64

# %%
# number: The car number that completed the lap
# driver_number: The driver of the car number that completed the lap
# lap_number: The lap number of the race the lap was completed at
# lap_time: The lap time recorded as they crossed the timing beam
# lap_improvement: Haven't looked into this, but my guess would a variable showing if the driver made improvement vs previous lap_times. Likely 0 is no improvement, 1 is green (personal best), 2 is purple (race best), and 3 is a WR? 99% of the laps have 0 improvement, so further research probably needed.
# crossing_finish_line_in_pit: boolean for if they crossed the finish line, B if they did, nan else
# s1, s2, s3 The sector times recorded as they crossed the timing beam (recorded in ss.mss)
# s1/s2/s3_improvement similar to lap_improvement
# s1/s2/s3_large: how they crossed the timing beams similar to lap_time
# kph: the average kph of the lap
# top_speed: the fastest recorded time of the lap
# driver_name: the driver that recorded the lap
# pit_time: the recorded time that was spent in the pitlane (typically followed by "B" in crossing_finish_line_in_pit)
# class: the class of the car that set the lap time
# group: the group of the car that set the lap time, only applicable to LMP1s and LMP2 Pro/Am (2021 season?)
# team: the team of the car that set the lap
# manufacturer: the manufacturer of the car that set the lap
# season: the WEC season the lap was set at
# circuit: the circuit the lap was set at
# round: the round (race number in the championship) the lap was set at
# vehicle: the car the lap was set with
# flag_at_fl: the flag status at the timing beam (only for 2022)
# lap_time_ms: The lap time recorded in milliseconds (seconds*1000)
# lap_time_s: the lap time recorded in seconds
# team_no: A combination of team and the team's number e.g Toyota Gazoo Racing #7
# engine: The engine of the car the lap was set with.
# driver_stint_no: Labeling the driver stint. A stint changes when the driver pits and either a. stays in the car, or b. swaps into the car.
# driver_stint: A combination of driver_name and the driver_stint_no, e.g. Mike CONWAY Stint #1
# team_stint_no: Labeling the team stint. A stint changes when the driver pits.
# team_stint: A combination of team_no and the team_stint_no, e.g. Toyota Gazoo Racing #7 Stint #1
# position: The position of the car at the time of the lap.
# class_position: The position of the car in class at the time of the lap.
# interval_ms: The interval (gap to the car in front for position) in ms
# interval: The interval (gap to the car in front for position) in s
# gap: The total time to the leader (time to 1st position overall) in s
# class_interval: The interval (gap to the car in front for position in class) in s
# class_gap The total time to the leader (time to 1st position in class) in s

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503680 entries, 0 to 503679
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   503680 non-null  int64
#  1   number                       503680 non-null  int64
#  2   driver_number                503680 non-null  int64
#  3   lap_number                   503680 non-null  int64
#  4   lap_time                     503680 non-null  object
#  5   lap_improvement              503680 non-null  int64
#  6   crossing_finish_line_in_pit  28445 non-null   object
#  7   s1                           503569 non-null  float64
#  8   s1_improvement               503680 non-null  int64
#  9   s2                           503406 non-null  float64
#  10  s2_improvement               503680 non-null  int64
#  11  s3                           503486 non-null  float64
#  12  s3_improvement               503680 non-null  int64
#  13  kph                          503680 non-null  float64
#  14  elapsed                      503680 non-null  object
#  15  hour                         503680 non-null  object
#  16  s1_large                     503564 non-null  object
#  17  s2_large                     503399 non-null  object
#  18  s3_large                     503479 non-null  object
#  19  top_speed                    501731 non-null  float64
#  20  driver_name                  503680 non-null  object
#  21  pit_time                     28644 non-null   object
#  22  class                        503680 non-null  object
#  23  group                        80562 non-null   object
#  24  team                         503680 non-null  object
#  25  manufacturer                 503680 non-null  object
#  26  season                       503680 non-null  object
#  27  circuit                      503680 non-null  object
#  28  round                        503680 non-null  int64
#  29  vehicle                      503680 non-null  object
#  30  flag_at_fl                   30294 non-null   object
#  31  team_no                      503680 non-null  object
#  32  lap_time_ms                  503680 non-null  float64
#  33  lap_time_s                   503680 non-null  float64
#  34  engine                       503680 non-null  object
#  35  driver_stint_no              503680 non-null  int64
#  36  driver_stint                 503680 non-null  object
#  37  team_stint_no                503680 non-null  int64
#  38  team_stint                   503680 non-null  object
#  39  elapsed_ms                   503680 non-null  int64
#  40  position                     503680 non-null  float64
#  41  class_position               503680 non-null  float64
#  42  interval_ms                  503680 non-null  float64
#  43  interval                     503680 non-null  float64
#  44  gap                          503680 non-null  float64
#  45  class_interval               503680 non-null  float64
#  46  class_gap                    503680 non-null  float64
#  47  elapsed_s                    503680 non-null  float64
# dtypes: float64(15), int64(12), object(21)
# memory usage: 184.5+ MB
# None

# %%
df.describe()
# Out:
#          Unnamed: 0         number  driver_number     lap_number  \
# count  503680.00000  503680.000000  503680.000000  503680.000000
# mean   251839.50000      53.766256       1.341775     118.358517
# std    145400.03613      67.623157       0.940485      83.514817
# min         0.00000       0.000000       0.000000       1.000000
# 25%    125919.75000      25.000000       1.000000      52.000000
# 50%    251839.50000      47.000000       1.000000     104.000000
# 75%    377759.25000      77.000000       2.000000     166.000000
# max    503679.00000     777.000000       3.000000     395.000000
#
#        lap_improvement             s1  s1_improvement             s2  \
# count    503680.000000  503569.000000   503680.000000  503406.000000
# mean          0.010076      44.221335        0.018857      63.995318
# std           0.143167     111.896698        0.170342      29.421726
# min           0.000000      16.690000        0.000000      25.266000
# 25%           0.000000      33.644000        0.000000      42.750000
# 50%           0.000000      36.712000        0.000000      52.883500
# 75%           0.000000      39.343000        0.000000      85.384000
# max           3.000000   18025.929000        3.000000    3646.889000
#
#        s2_improvement             s3  ...  team_stint_no    elapsed_ms  \
# count   503680.000000  503486.000000  ...  503680.000000  5.036800e+05
# mean         0.018887      65.954284  ...       8.182618  2.251623e+07
# std          0.170484      48.209154  ...       8.055612  2.175151e+07
# min          0.000000      15.220000  ...       0.000000  8.438800e+04
# 25%          0.000000      35.252000  ...       3.000000  7.497529e+06
# 50%          0.000000      44.798000  ...       5.000000  1.514634e+07
# 75%          0.000000     102.728000  ...      10.000000  2.769537e+07
# max          3.000000    3653.638000  ...      50.000000  8.692520e+07
#
#             position  class_position   interval_ms       interval  \
# count  503680.000000   503680.000000  5.036800e+05  503680.000000
# mean       18.534333        5.700790  1.589048e+05     158.904821
# std        12.772971        4.364912  5.976172e+05     597.617202
# min         1.000000        1.000000  0.000000e+00       0.000000
# 25%         8.000000        2.000000  6.773000e+03       6.773000
# 50%        17.000000        5.000000  3.163300e+04      31.633000
# 75%        26.000000        8.000000  1.165655e+05     116.565500
# max        62.000000       27.000000  2.455741e+07   24557.407000
#
#                  gap  class_interval      class_gap      elapsed_s
# count  503680.000000   503680.000000  503680.000000  503680.000000
# mean     2179.684949      131.506613     420.611197   22516.229955
# std      2859.444803      582.349385     985.250399   21751.510146
# min         0.000000        0.000000       0.000000      84.388000
# 25%       338.071750        2.748000      15.846000    7497.528750
# 50%      1182.121000       20.409000      96.684500   15146.341500
# 75%      2634.542250       83.238250     375.221000   27695.366750
# max     40495.937000    24557.407000   27002.532000   86925.196000
#
# [8 rows x 27 columns]

# %%
df.shape
# Out:
# (503680, 48)

# %% [markdown]
# #### Preprocessing

# %%
df.isna().sum()
# Out:
# Unnamed: 0                          0
# number                              0
# driver_number                       0
# lap_number                          0
# lap_time                            0
# lap_improvement                     0
# crossing_finish_line_in_pit    475235
# s1                                111
# s1_improvement                      0
# s2                                274
# s2_improvement                      0
# s3                                194
# s3_improvement                      0
# kph                                 0
# elapsed                             0
# hour                                0
# s1_large                          116
# s2_large                          281
# s3_large                          201
# top_speed                        1949
# driver_name                         0
# pit_time                       475036
# class                               0
# group                          423118
# team                                0
# manufacturer                        0
# season                              0
# circuit                             0
# round                               0
# vehicle                             0
# flag_at_fl                     473386
# team_no                             0
# lap_time_ms                         0
# lap_time_s                          0
# engine                              0
# driver_stint_no                     0
# driver_stint                        0
# team_stint_no                       0
# team_stint                          0
# elapsed_ms                          0
# position                            0
# class_position                      0
# interval_ms                         0
# interval                            0
# gap                                 0
# class_interval                      0
# class_gap                           0
# elapsed_s                           0
# dtype: int64

# %%
# Removing columns With large number of missing values

df.drop(columns=['crossing_finish_line_in_pit','group','flag_at_fl','pit_time'],axis=1,inplace=True)
df.shape
# Out:
# (503680, 44)

# %%
# fill ing missing values

df['s1']=df['s1'].fillna(df['s1'].mean())
df['s2']=df['s2'].fillna(df['s2'].mean())
df['s3']=df['s3'].fillna(df['s3'].mean())
df['top_speed']=df['top_speed'].fillna(df['top_speed'].median())
df['s1_large']=df['s1_large'].fillna(df['s1_large'].mode()[0])
df['s2_large']=df['s2_large'].fillna(df['s2_large'].mode()[0])
df['s3_large']=df['s3_large'].fillna(df['s3_large'].mode()[0])

df.isna().sum()
# Out:
# Unnamed: 0         0
# number             0
# driver_number      0
# lap_number         0
# lap_time           0
# lap_improvement    0
# s1                 0
# s1_improvement     0
# s2                 0
# s2_improvement     0
# s3                 0
# s3_improvement     0
# kph                0
# elapsed            0
# hour               0
# s1_large           0
# s2_large           0
# s3_large           0
# top_speed          0
# driver_name        0
# class              0
# team               0
# manufacturer       0
# season             0
# circuit            0
# round              0
# vehicle            0
# team_no            0
# lap_time_ms        0
# lap_time_s         0
# engine             0
# driver_stint_no    0
# driver_stint       0
# team_stint_no      0
# team_stint         0
# elapsed_ms         0
# position           0
# class_position     0
# interval_ms        0
# interval           0
# gap                0
# class_interval     0
# class_gap          0
# elapsed_s          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'number', 'driver_number', 'lap_number', 'lap_time',
#        'lap_improvement', 's1', 's1_improvement', 's2', 's2_improvement', 's3',
#        's3_improvement', 'kph', 'elapsed', 'hour', 's1_large', 's2_large',
#        's3_large', 'top_speed', 'driver_name', 'class', 'team', 'manufacturer',
#        'season', 'circuit', 'round', 'vehicle', 'team_no', 'lap_time_ms',
#        'lap_time_s', 'engine', 'driver_stint_no', 'driver_stint',
#        'team_stint_no', 'team_stint', 'elapsed_ms', 'position',
#        'class_position', 'interval_ms', 'interval', 'gap', 'class_interval',
#        'class_gap', 'elapsed_s'],
#       dtype='object')

# %%
df['class'].unique()
# Out:
# array(['LMGTE Am', 'LMGTE Pro', 'LMP1', 'LMP2', 'CDNT', 'LMP1-H',
#        'LMP1-L', 'HYPERCAR', 'INNOVATIVE CAR'], dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='class',data=df,palette='pastel')
plt.title('Vehicle Class Count')
plt.show()
# Out:
# C:\Users\joeva\AppData\Local\Temp\ipykernel_24924\2810177227.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class',data=df,palette='pastel')

# %%
plt.figure(figsize=(7,7))
plt.pie(df['class'].value_counts(),labels=df['class'].unique())
plt.title('Vehicle Class Count')
plt.legend(loc='lower left')
plt.show()

# %%
df['class'].value_counts()
# Out:
# class
# LMP2              168680
# LMGTE Am          131889
# LMGTE Pro         101579
# LMP1               79703
# LMP1-H              9978
# HYPERCAR            8512
# LMP1-L              2610
# CDNT                 395
# INNOVATIVE CAR       334
# Name: count, dtype: int64

# %%
correlation = df.corr(numeric_only=True)
correlation
# Out:
#                  Unnamed: 0    number  driver_number  lap_number  \
# Unnamed: 0         1.000000  0.152717       0.452919    0.095062
# number             0.152717  1.000000       0.060586   -0.004937
# driver_number      0.452919  0.060586       1.000000    0.112882
# lap_number         0.095062 -0.004937       0.112882    1.000000
# lap_improvement   -0.003373 -0.000302       0.006348   -0.005095
# s1                -0.003881  0.002528       0.001668    0.000449
# s1_improvement    -0.003862 -0.000468       0.000977   -0.010673
# s2                 0.064071  0.057649       0.096766    0.251113
# s2_improvement    -0.003995 -0.000492       0.000430   -0.012694
# s3                 0.103215  0.050256       0.111172    0.273347
# s3_improvement    -0.003840 -0.000686       0.000087   -0.008582
# kph                0.101325 -0.070032       0.122696    0.278285
# top_speed          0.117318 -0.067412       0.084836    0.210108
# round              0.065604 -0.033536      -0.010834   -0.042202
# lap_time_ms        0.042690  0.029573       0.056717    0.139225
# lap_time_s         0.042690  0.029573       0.056717    0.139225
# driver_stint_no    0.126190 -0.022352       0.119043    0.816776
# team_stint_no      0.142799 -0.023471       0.137494    0.874654
# elapsed_ms         0.108631  0.024536       0.125427    0.909503
# position           0.155152  0.249014       0.096540    0.020658
# class_position     0.210794 -0.000028       0.125226    0.071220
# interval_ms       -0.031325  0.002826       0.015109    0.157808
# interval          -0.031325  0.002826       0.015109    0.157808
# gap                0.002395  0.093921       0.052141    0.622642
# class_interval    -0.027880  0.004187       0.017812    0.129993
# class_gap         -0.010323 -0.019411       0.035509    0.352801
# elapsed_s          0.108631  0.024536       0.125427    0.909503
#
#                  lap_improvement        s1  s1_improvement        s2  \
# Unnamed: 0             -0.003373 -0.003881       -0.003862  0.064071
# number                 -0.000302  0.002528       -0.000468  0.057649
# driver_number           0.006348  0.001668        0.000977  0.096766
# lap_number             -0.005095  0.000449       -0.010673  0.251113
# lap_improvement         1.000000 -0.006114        0.211529 -0.021345
# s1                     -0.006114  1.000000       -0.009457  0.076707
# s1_improvement          0.211529 -0.009457        1.000000 -0.027185
# s2                     -0.021345  0.076707       -0.027185  1.000000
# s2_improvement          0.338886 -0.003624        0.129869 -0.030769
# s3                     -0.019792  0.049355       -0.023872  0.690158
# s3_improvement          0.326417 -0.003258        0.094173 -0.028387
# kph                     0.017640 -0.247452        0.017795  0.134603
# top_speed               0.010458 -0.080940        0.017398 -0.124675
# round                   0.000860 -0.013265        0.000270 -0.174918
# lap_time_ms            -0.015423  0.862935       -0.020512  0.484336
# lap_time_s             -0.015423  0.862935       -0.020512  0.484336
# driver_stint_no        -0.004079  0.025628       -0.017637  0.429694
# team_stint_no          -0.006373  0.028247       -0.013648  0.471505
# elapsed_ms             -0.007413  0.029485       -0.013713  0.493342
# position               -0.006356  0.061496       -0.007427  0.407149
# class_position         -0.008046  0.051093       -0.009215  0.320668
# interval_ms            -0.000332  0.096799       -0.000727  0.110207
# interval               -0.000332  0.096799       -0.000727  0.110207
# gap                    -0.003523  0.075229       -0.008353  0.456218
# class_interval          0.000613  0.099828        0.000034  0.106857
# class_gap              -0.001747  0.102484       -0.004201  0.271947
# elapsed_s              -0.007413  0.029485       -0.013713  0.493342
#
#                  s2_improvement        s3  ...  team_stint_no  elapsed_ms  \
# Unnamed: 0            -0.003995  0.103215  ...       0.142799    0.108631
# number                -0.000492  0.050256  ...      -0.023471    0.024536
# driver_number          0.000430  0.111172  ...       0.137494    0.125427
# lap_number            -0.012694  0.273347  ...       0.874654    0.909503
# lap_improvement        0.338886 -0.019792  ...      -0.006373   -0.007413
# s1                    -0.003624  0.049355  ...       0.028247    0.029485
# s1_improvement         0.129869 -0.023872  ...      -0.013648   -0.013713
# s2                    -0.030769  0.690158  ...       0.471505    0.493342
# s2_improvement         1.000000 -0.025459  ...      -0.013597   -0.014581
# s3                    -0.025459  1.000000  ...       0.454573    0.477531
# s3_improvement         0.158487 -0.029087  ...      -0.009020   -0.010097
# kph                    0.009631  0.166093  ...       0.408168    0.385827
# top_speed              0.012281  0.063570  ...       0.299214    0.265432
# round                  0.000245 -0.098770  ...      -0.105341   -0.095067
# lap_time_ms           -0.017284  0.502865  ...       0.263829    0.277004
# lap_time_s            -0.017284  0.502865  ...       0.263829    0.277004
# driver_stint_no       -0.017055  0.421752  ...       0.932284    0.898017
# team_stint_no         -0.013597  0.454573  ...       1.000000    0.959214
# elapsed_ms            -0.014581  0.477531  ...       0.959214    1.000000
# position              -0.007222  0.366041  ...       0.121864    0.204999
# class_position        -0.007720  0.308628  ...       0.260177    0.208042
# interval_ms           -0.000914  0.110132  ...       0.187617    0.209861
# interval              -0.000914  0.110132  ...       0.187617    0.209861
# gap                   -0.008573  0.425967  ...       0.658903    0.769287
# class_interval         0.000189  0.107173  ...       0.169100    0.189721
# class_gap             -0.004680  0.266858  ...       0.472581    0.464398
# elapsed_s             -0.014581  0.477531  ...       0.959214    1.000000
#
#                  position  class_position  interval_ms  interval       gap  \
# Unnamed: 0       0.155152        0.210794    -0.031325 -0.031325  0.002395
# number           0.249014       -0.000028     0.002826  0.002826  0.093921
# driver_number    0.096540        0.125226     0.015109  0.015109  0.052141
# lap_number       0.020658        0.071220     0.157808  0.157808  0.622642
# lap_improvement -0.006356       -0.008046    -0.000332 -0.000332 -0.003523
# s1               0.061496        0.051093     0.096799  0.096799  0.075229
# s1_improvement  -0.007427       -0.009215    -0.000727 -0.000727 -0.008353
# s2               0.407149        0.320668     0.110207  0.110207  0.456218
# s2_improvement  -0.007222       -0.007720    -0.000914 -0.000914 -0.008573
# s3               0.366041        0.308628     0.110132  0.110132  0.425967
# s3_improvement  -0.007061       -0.007659    -0.000278 -0.000278 -0.004383
# kph              0.005981        0.162739     0.032777  0.032777  0.185034
# top_speed       -0.028945        0.141342     0.020453  0.020453  0.106753
# round           -0.068755       -0.068257    -0.034606 -0.034606 -0.085081
# lap_time_ms      0.249683        0.205267     0.143333  0.143333  0.292012
# lap_time_s       0.249683        0.205267     0.143333  0.143333  0.292012
# driver_stint_no  0.101305        0.232321     0.176506  0.176506  0.617102
# team_stint_no    0.121864        0.260177     0.187617  0.187617  0.658903
# elapsed_ms       0.204999        0.208042     0.209861  0.209861  0.769287
# position         1.000000        0.549269     0.150593  0.150593  0.541946
# class_position   0.549269        1.000000     0.133618  0.133618  0.332168
# interval_ms      0.150593        0.133618     1.000000  1.000000  0.425073
# interval         0.150593        0.133618     1.000000  1.000000  0.425073
# gap              0.541946        0.332168     0.425073  0.425073  1.000000
# class_interval   0.177558        0.187789     0.964099  0.964099  0.424497
# class_gap        0.308710        0.478503     0.733055  0.733055  0.666300
# elapsed_s        0.204999        0.208042     0.209861  0.209861  0.769287
#
#                  class_interval  class_gap  elapsed_s
# Unnamed: 0            -0.027880  -0.010323   0.108631
# number                 0.004187  -0.019411   0.024536
# driver_number          0.017812   0.035509   0.125427
# lap_number             0.129993   0.352801   0.909503
# lap_improvement        0.000613  -0.001747  -0.007413
# s1                     0.099828   0.102484   0.029485
# s1_improvement         0.000034  -0.004201  -0.013713
# s2                     0.106857   0.271947   0.493342
# s2_improvement         0.000189  -0.004680  -0.014581
# s3                     0.107173   0.266858   0.477531
# s3_improvement         0.001061  -0.002583  -0.010097
# kph                    0.029827   0.148804   0.385827
# top_speed              0.019919   0.111137   0.265432
# round                 -0.036176  -0.081615  -0.095067
# lap_time_ms            0.144401   0.228734   0.277004
# lap_time_s             0.144401   0.228734   0.277004
# driver_stint_no        0.156932   0.437046   0.898017
# team_stint_no          0.169100   0.472581   0.959214
# elapsed_ms             0.189721   0.464398   1.000000
# position               0.177558   0.308710   0.204999
# class_position         0.187789   0.478503   0.208042
# interval_ms            0.964099   0.733055   0.209861
# interval               0.964099   0.733055   0.209861
# gap                    0.424497   0.666300   0.769287
# class_interval         1.000000   0.772359   0.189721
# class_gap              0.772359   1.000000   0.464398
# elapsed_s              0.189721   0.464398   1.000000
#
# [27 rows x 27 columns]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(correlation,cmap='plasma',linecolor='white',linewidths=0.3)
# Out:
# <Axes: >

# %%
#Removing unvanted columns and columns with duplicate values
df.drop(columns=['Unnamed: 0','driver_name','lap_time','lap_time_ms','team_no','s1_improvement','s2_improvement','s3_improvement','s1_large','s2_large','s3_large','lap_improvement','elapsed_s','elapsed','hour','driver_stint','team_stint','vehicle','class_position','engine'],axis=1,inplace=True)
df.shape
# Out:
# (503680, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503680 entries, 0 to 503679
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   number           503680 non-null  int64
#  1   driver_number    503680 non-null  int64
#  2   lap_number       503680 non-null  int64
#  3   s1               503680 non-null  float64
#  4   s2               503680 non-null  float64
#  5   s3               503680 non-null  float64
#  6   kph              503680 non-null  float64
#  7   top_speed        503680 non-null  float64
#  8   class            503680 non-null  object
#  9   team             503680 non-null  object
#  10  manufacturer     503680 non-null  object
#  11  season           503680 non-null  object
#  12  circuit          503680 non-null  object
#  13  round            503680 non-null  int64
#  14  lap_time_s       503680 non-null  float64
#  15  driver_stint_no  503680 non-null  int64
#  16  team_stint_no    503680 non-null  int64
#  17  elapsed_ms       503680 non-null  int64
#  18  position         503680 non-null  float64
#  19  interval_ms      503680 non-null  float64
#  20  interval         503680 non-null  float64
#  21  gap              503680 non-null  float64
#  22  class_interval   503680 non-null  float64
#  23  class_gap        503680 non-null  float64
# dtypes: float64(12), int64(7), object(5)
# memory usage: 92.2+ MB

# %%
df['season'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, '2017', '2018-2019',
#        '2019-2020', '2021', 2021, 2022], dtype=object)

# %%
# Converting the feature 'season' from mixed dtypes to int dtype

df['season']=df['season'].astype(str)
df[['season_start','season_end']]=df['season'].str.split('-',expand=True)
df['season_start'].value_counts()
# Out:
# season_start
# 2018    69443
# 2016    62095
# 2012    54432
# 2017    53964
# 2019    52972
# 2015    52702
# 2021    50051
# 2014    43644
# 2013    34083
# 2022    30294
# Name: count, dtype: int64

# %%
#Dropping season and season end

df.drop(columns=['season','season_end'],axis=1,inplace=True)

# %%
# Convert 'season_start' to integer
df['season_start'] = pd.to_numeric(df['season_start'])

# %%
df['circuit'].unique()
# Out:
# array(['SEBRING', 'SPA FRANCORCHAMPS', 'LE MANS', 'INTERLAGOS',
#        'SILVERSTONE', 'BAHRAIN INTERNATIONAL CIRCUIT', 'FUJI SPEEDWAY',
#        'SHANGHAI INTERNATIONAL CIRCUIT', 'CIRCUIT OF THE AMERICAS',
#        'NURBURGRING', 'AUTODROMO HERMANOS RODRIGUEZ', 'LE MANS 2018',
#        'SPA FRANCORCHAMPS 2019', 'LE MANS 2019',
#        'BAHRAIN INTERNATIONAL CIRCUIT 2019',
#        'BAHRAIN INTERNATIONAL CIRCUIT 2020', 'AUTODROMO DO ALGARVE',
#        'AUTODROMO NAZIONALE DI MONZA',
#        'BAHRAIN INTERNATIONAL CIRCUIT 6 HOURS',
#        'BAHRAIN INTERNATIONAL CIRCUIT 8 HOURS'], dtype=object)

# %% [markdown]
# LE MANS                                   11 /
# SPA FRANCORCHAMPS                         18 /
# FUJI SPEEDWAY                             9  /
# SILVERSTONE                               17 /
# SHANGHAI INTERNATIONAL CIRCUIT            16 /
# BAHRAIN INTERNATIONAL CIRCUIT             3 /
# CIRCUIT OF THE AMERICAS                   8 /
# SEBRING                                   15 /
# LE MANS 2019                              13 /
# LE MANS 2018                              12 /
# NURBURGRING                               14 /
# INTERLAGOS                                10 /
# AUTODROMO HERMANOS RODRIGUEZ              1 /
# AUTODROMO DO ALGARVE                       0 /
# BAHRAIN INTERNATIONAL CIRCUIT 2019         4 /
# BAHRAIN INTERNATIONAL CIRCUIT 8 HOURS      7 /
# AUTODROMO NAZIONALE DI MONZA               2 /
# BAHRAIN INTERNATIONAL CIRCUIT 2020         5 /
# BAHRAIN INTERNATIONAL CIRCUIT 6 HOURS      6 /
# SPA FRANCORCHAMPS 2019                     19

# %%
df['manufacturer'].unique()
# Out:
# array(['Ferrari', 'Porsche', 'Chevrolet', 'Aston Martin', 'Audi', 'Lola',
#        'HPD (Honda)', 'Dome', 'Oak', 'Morgan', 'Zytek', 'Oreca', 'Norma',
#        'Nissan', 'Toyota', 'Rebellion', 'Ligier', 'Alpine', 'CLM', 'HPD',
#        'Gibson', 'Strakka', 'Srt', 'BR01', 'Ford', 'LIGIER', 'ENSO',
#        'Enso', 'Dallara', 'Riley', 'BMW', 'BR Engineering', 'Ginetta',
#        'Aurus', 'Glickenhaus'], dtype=object)

# %%
# coverting all strings to lowercase and removes  digits, whitespaces and the hour from circuits
import re
cols = ['circuit', 'manufacturer','team']
df['circuit'] = df['circuit'].str.replace(r'\d+', '', regex=True)
df['circuit'] = [re.sub(r'(?i)\b(hours?)\b', '', s).strip() for s in df['circuit']]
df[cols] = df[cols].apply(lambda x: x.str.lower().str.replace(' ', '_', regex=True))
df['circuit'].unique()
# Out:
# array(['sebring', 'spa_francorchamps', 'le_mans', 'interlagos',
#        'silverstone', 'bahrain_international_circuit', 'fuji_speedway',
#        'shanghai_international_circuit', 'circuit_of_the_americas',
#        'nurburgring', 'autodromo_hermanos_rodriguez',
#        'autodromo_do_algarve', 'autodromo_nazionale_di_monza'],
#       dtype=object)

# %%
df.shape
# Out:
# (503680, 24)

# %%
df = df[~df['class'].isin(['LMP1-L', 'CDNT', 'INNOVATIVE CAR'])]
df.reset_index(drop=True,inplace=True)
df.shape
# Out:
# (500341, 24)

# %%
outlier_columns=['top_speed','kph','position','lap_number','lap_time_s']

def remove_outlier(df,columns):
    for col in columns:
        
        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        
        IQR=Q3-Q1
        
        lower_bound=Q1-1.5*IQR
        upper_bound=Q3+1.5*IQR
        
        df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]
    return df

cleaned_df=remove_outlier(df,outlier_columns)
cleaned_df.reset_index(drop=True,inplace=True)
cleaned_df.shape
# Out:
# (457114, 24)

# %%
# Undersampling

from imblearn.under_sampling import RandomUnderSampler


x=cleaned_df.drop('class',axis=1)
y=cleaned_df['class']

threshold=5000
class_counts=y.value_counts()
SampleStrategy={lable:threshold for lable, count in class_counts.items() if count > threshold}

RUS=RandomUnderSampler(sampling_strategy=SampleStrategy,random_state=42)

undersampled_x,undersampled_y=RUS.fit_resample(x,y)

undersampled_df=pd.DataFrame(undersampled_x)
undersampled_y=pd.DataFrame(undersampled_y)
undersampled_df=pd.concat((undersampled_df,undersampled_y),axis=1)
undersampled_df
# Out:
#         number  driver_number  lap_number      s1       s2       s3    kph  \
# 444525       8              3          88  33.272   80.236   98.853  231.0
# 434943      36              2         100  32.663   38.400   38.501  197.8
# 398551     708              1           7  31.404   34.254   33.924  209.4
# 425925       8              1          36  34.349   41.644   34.984  175.6
# 456382     708              3         324  37.478   81.943   97.705  225.9
# ...        ...            ...         ...     ...      ...      ...    ...
# 275832      25              1         162  35.873   41.780   35.586  172.1
# 332908      23              1         254  34.500   81.740  100.161  226.7
# 249032      27              0         281  85.404  125.205  105.002  155.5
# 101396      27              1           9  25.806   45.601   48.218  166.0
# 427283      29              3          82  35.909   42.881   36.242  169.4
#
#         top_speed                       team manufacturer  ... team_stint_no  \
# 444525      333.9        toyota_gazoo_racing       toyota  ...             8
# 434943      283.1            alpine_elf_team       alpine  ...             3
# 398551      291.9         glickenhaus_racing  glickenhaus  ...             1
# 425925      272.3        toyota_gazoo_racing       toyota  ...             2
# 456382      326.8         glickenhaus_racing  glickenhaus  ...            30
# ...           ...                        ...          ...  ...           ...
# 275832      263.0      cefc_manor_trs_racing        oreca  ...             8
# 332908      330.8  panis_barthez_competition       ligier  ...            26
# 249032      319.1                 smp_racing      dallara  ...            33
# 101396      266.7                 smp_racing        oreca  ...             1
# 427283      266.2      racing_team_nederland        oreca  ...             4
#
#         elapsed_ms  position  interval_ms  interval       gap  class_interval  \
# 444525    19496956       2.0       6975.0     6.975     6.975           6.975
# 434943    11330557       1.0          0.0     0.000     0.000           0.000
# 398551      701419       5.0       9592.0     9.592    15.807           9.592
# 425925     4084665       2.0       4041.0     4.041     4.041           4.041
# 456382    76432331       6.0      19712.0    19.712  2351.817          19.712
# ...            ...       ...          ...       ...       ...             ...
# 275832    19102065      10.0        656.0     0.656  1378.353           0.656
# 332908    61690581      13.0     318810.0   318.810  4221.610         318.810
# 249032    73694646      28.0     190191.0   190.191  9007.944         190.191
# 101396     1080871      11.0      16613.0    16.613    77.193          16.613
# 427283     9962022       6.0      33921.0    33.921   442.412          33.921
#
#         class_gap  season_start     class
# 444525      6.975          2022  HYPERCAR
# 434943      0.000          2022  HYPERCAR
# 398551     15.807          2021  HYPERCAR
# 425925      4.041          2021  HYPERCAR
# 456382   1095.250          2022  HYPERCAR
# ...           ...           ...       ...
# 275832    104.328          2017      LMP2
# 332908   1170.574          2018      LMP2
# 249032   5401.359          2017      LMP2
# 101396     17.788          2014      LMP2
# 427283     58.727          2021      LMP2
#
# [30000 rows x 24 columns]

# %%
# reset index values

undersampled_df.reset_index(drop=True,inplace=True)
undersampled_df
# Out:
#        number  driver_number  lap_number      s1       s2       s3    kph  \
# 0           8              3          88  33.272   80.236   98.853  231.0
# 1          36              2         100  32.663   38.400   38.501  197.8
# 2         708              1           7  31.404   34.254   33.924  209.4
# 3           8              1          36  34.349   41.644   34.984  175.6
# 4         708              3         324  37.478   81.943   97.705  225.9
# ...       ...            ...         ...     ...      ...      ...    ...
# 29995      25              1         162  35.873   41.780   35.586  172.1
# 29996      23              1         254  34.500   81.740  100.161  226.7
# 29997      27              0         281  85.404  125.205  105.002  155.5
# 29998      27              1           9  25.806   45.601   48.218  166.0
# 29999      29              3          82  35.909   42.881   36.242  169.4
#
#        top_speed                       team manufacturer  ... team_stint_no  \
# 0          333.9        toyota_gazoo_racing       toyota  ...             8
# 1          283.1            alpine_elf_team       alpine  ...             3
# 2          291.9         glickenhaus_racing  glickenhaus  ...             1
# 3          272.3        toyota_gazoo_racing       toyota  ...             2
# 4          326.8         glickenhaus_racing  glickenhaus  ...            30
# ...          ...                        ...          ...  ...           ...
# 29995      263.0      cefc_manor_trs_racing        oreca  ...             8
# 29996      330.8  panis_barthez_competition       ligier  ...            26
# 29997      319.1                 smp_racing      dallara  ...            33
# 29998      266.7                 smp_racing        oreca  ...             1
# 29999      266.2      racing_team_nederland        oreca  ...             4
#
#        elapsed_ms  position  interval_ms  interval       gap  class_interval  \
# 0        19496956       2.0       6975.0     6.975     6.975           6.975
# 1        11330557       1.0          0.0     0.000     0.000           0.000
# 2          701419       5.0       9592.0     9.592    15.807           9.592
# 3         4084665       2.0       4041.0     4.041     4.041           4.041
# 4        76432331       6.0      19712.0    19.712  2351.817          19.712
# ...           ...       ...          ...       ...       ...             ...
# 29995    19102065      10.0        656.0     0.656  1378.353           0.656
# 29996    61690581      13.0     318810.0   318.810  4221.610         318.810
# 29997    73694646      28.0     190191.0   190.191  9007.944         190.191
# 29998     1080871      11.0      16613.0    16.613    77.193          16.613
# 29999     9962022       6.0      33921.0    33.921   442.412          33.921
#
#        class_gap  season_start     class
# 0          6.975          2022  HYPERCAR
# 1          0.000          2022  HYPERCAR
# 2         15.807          2021  HYPERCAR
# 3          4.041          2021  HYPERCAR
# 4       1095.250          2022  HYPERCAR
# ...          ...           ...       ...
# 29995    104.328          2017      LMP2
# 29996   1170.574          2018      LMP2
# 29997   5401.359          2017      LMP2
# 29998     17.788          2014      LMP2
# 29999     58.727          2021      LMP2
#
# [30000 rows x 24 columns]

# %%
undersampled_df.shape
# Out:
# (30000, 24)

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(sparse_output=False, drop='first')
encoded_features = ohe.fit_transform(undersampled_df[['circuit', 'manufacturer']])
df_encoded = pd.DataFrame(encoded_features, columns=ohe.get_feature_names_out(['circuit', 'manufacturer']))

df1 = pd.concat([undersampled_df, df_encoded], axis=1).drop(columns=['circuit'])

# %%
from category_encoders import TargetEncoder

team_enc = TargetEncoder()
df1['team_encoded'] = team_enc.fit_transform(undersampled_df['team'],undersampled_df['class'])

manufacturer_enc = TargetEncoder()
df1['manufacturer_encoded'] = manufacturer_enc.fit_transform(undersampled_df['manufacturer'],undersampled_df['class'])

df1.drop(columns=['team', 'manufacturer'], inplace=True)

# %%
import pickle

with open("team_encoder.pkl", "wb") as f:
    pickle.dump(team_enc, f)

with open("manufacturer_encoder.pkl", "wb") as f:
    pickle.dump(manufacturer_enc, f)

# %% [markdown]
# #### Visualization

# %%
#droping interval_ms, interval, elapsed_ms,gap,class_interval,class_gap as thay do not affect classification

df.drop(columns=['interval_ms', 'interval', 'elapsed_ms','gap','class_interval','class_gap','s1','s2','s3'],axis=1,inplace=True)
plt.figure(figsize=(20,10))
sns.boxplot(df)
# Out:
# C:\Users\joeva\AppData\Local\Temp\ipykernel_24924\1838040044.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['interval_ms', 'interval', 'elapsed_ms','gap','class_interval','class_gap','s1','s2','s3'],axis=1,inplace=True)
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sns.boxplot(undersampled_df.drop(columns=['number','season_start'],axis=1))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='class',data=undersampled_df,palette='pastel')
plt.title('Vehicle Class Count after Undersampling')
plt.show()
# Out:
# C:\Users\joeva\AppData\Local\Temp\ipykernel_24924\1615867066.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class',data=undersampled_df,palette='pastel')

# %%
class_order = ['LMGTE Am','LMGTE Pro','LMP 1','LMP 2','LMP1-H','HYPERCAR']
plt.figure(figsize=(7,7))
plt.pie(undersampled_df['class'].value_counts(),labels=class_order,autopct='%1.f%%')
plt.title('Vehicle Class Count after undersampling')
plt.legend(loc='lower left')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.set_theme(style='whitegrid')
sns.lineplot(data=undersampled_df, x='lap_number',y='lap_time_s',hue='class',linewidth=2.5)
plt.title('Lap Time Trend by Class', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Lap Number', fontsize=12, labelpad=10)
plt.ylabel('Lap Time (s)', fontsize=12, labelpad=10)
plt.legend(title='Class', title_fontsize='13', loc='best', frameon=True, shadow=True, fontsize=11)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=undersampled_df, x='top_speed', y='lap_time_s', hue='class')
plt.title('Top Speed vs Lap Time by Class')
plt.xlabel('Top Speed (kph)')
plt.ylabel('Lap Time (s)')
plt.show()

# %% [markdown]
# #### Model Creation

# %%
df1.drop(columns=['s1','s2','s3','elapsed_ms','interval_ms','interval_ms','gap','class_interval','class_gap','interval'],axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['number', 'driver_number', 'lap_number', 'kph', 'top_speed', 'round',
#        'lap_time_s', 'driver_stint_no', 'team_stint_no', 'position',
#        'season_start', 'class', 'circuit_autodromo_hermanos_rodriguez',
#        'circuit_autodromo_nazionale_di_monza',
#        'circuit_bahrain_international_circuit',
#        'circuit_circuit_of_the_americas', 'circuit_fuji_speedway',
#        'circuit_interlagos', 'circuit_le_mans', 'circuit_nurburgring',
#        'circuit_sebring', 'circuit_shanghai_international_circuit',
#        'circuit_silverstone', 'circuit_spa_francorchamps',
#        'manufacturer_aston_martin', 'manufacturer_audi', 'manufacturer_aurus',
#        'manufacturer_bmw', 'manufacturer_br01', 'manufacturer_br_engineering',
#        'manufacturer_chevrolet', 'manufacturer_clm', 'manufacturer_dallara',
#        'manufacturer_dome', 'manufacturer_enso', 'manufacturer_ferrari',
#        'manufacturer_ford', 'manufacturer_gibson', 'manufacturer_ginetta',
#        'manufacturer_glickenhaus', 'manufacturer_hpd',
#        'manufacturer_hpd_(honda)', 'manufacturer_ligier', 'manufacturer_lola',
#        'manufacturer_morgan', 'manufacturer_nissan', 'manufacturer_norma',
#        'manufacturer_oak', 'manufacturer_oreca', 'manufacturer_porsche',
#        'manufacturer_rebellion', 'manufacturer_riley', 'manufacturer_srt',
#        'manufacturer_strakka', 'manufacturer_toyota', 'manufacturer_zytek',
#        'team_encoded', 'manufacturer_encoded'],
#       dtype='object')

# %%
cori=df1.corr(numeric_only=True)
cori
# Out:
#                                           number  driver_number  lap_number  \
# number                                  1.000000       0.154973    0.055234
# driver_number                           0.154973       1.000000    0.116149
# lap_number                              0.055234       0.116149    1.000000
# kph                                     0.088066       0.145308    0.288588
# top_speed                               0.141804       0.191579    0.298276
# round                                  -0.109567      -0.086514   -0.029522
# lap_time_s                              0.140103       0.132936    0.326427
# driver_stint_no                         0.079765       0.104909    0.790305
# team_stint_no                           0.090010       0.136053    0.855867
# position                                0.073136       0.050297    0.038259
# season_start                            0.319872       0.477481    0.097332
# circuit_autodromo_hermanos_rodriguez   -0.023938      -0.070750   -0.019834
# circuit_autodromo_nazionale_di_monza    0.164142       0.111050   -0.045967
# circuit_bahrain_international_circuit  -0.075245       0.014237   -0.076304
# circuit_circuit_of_the_americas        -0.049837      -0.080336   -0.114540
# circuit_fuji_speedway                  -0.068950      -0.059137   -0.040262
# circuit_interlagos                     -0.062337      -0.108409    0.003472
# circuit_le_mans                         0.141767       0.145360    0.392998
# circuit_nurburgring                    -0.028831      -0.077746   -0.056839
# circuit_sebring                         0.048864       0.088708   -0.012137
# circuit_shanghai_international_circuit -0.061318      -0.096813   -0.112869
# circuit_silverstone                    -0.050046      -0.069241   -0.126356
# circuit_spa_francorchamps              -0.049578      -0.032390   -0.177858
# manufacturer_aston_martin               0.086136      -0.024073   -0.034657
# manufacturer_audi                      -0.144866      -0.140575   -0.019876
# manufacturer_aurus                     -0.011608       0.037857    0.013155
# manufacturer_bmw                        0.006447       0.019703   -0.008140
# manufacturer_br01                      -0.016474      -0.030648    0.001821
# manufacturer_br_engineering            -0.031524       0.041277   -0.020326
# manufacturer_chevrolet                 -0.006419      -0.004896    0.025146
# manufacturer_clm                       -0.034261      -0.049201   -0.027775
# manufacturer_dallara                   -0.016086       0.036529    0.016925
# manufacturer_dome                      -0.014926      -0.015959    0.005679
# manufacturer_enso                      -0.023566       0.014899   -0.034722
# manufacturer_ferrari                   -0.006928      -0.020999    0.000417
# manufacturer_ford                      -0.000870      -0.022163    0.009425
# manufacturer_gibson                    -0.011115      -0.015190   -0.005469
# manufacturer_ginetta                   -0.027315       0.026674   -0.023374
# manufacturer_glickenhaus                0.946538       0.149842    0.060947
# manufacturer_hpd                       -0.003376      -0.007581   -0.001216
# manufacturer_hpd_(honda)               -0.028220      -0.024389    0.006788
# manufacturer_ligier                    -0.039119      -0.018775    0.018558
# manufacturer_lola                      -0.036850      -0.066201   -0.009467
# manufacturer_morgan                    -0.022650      -0.027141    0.000561
# manufacturer_nissan                    -0.010744      -0.019987    0.001498
# manufacturer_norma                     -0.003481      -0.016340    0.003265
# manufacturer_oak                       -0.016213      -0.022141   -0.012402
# manufacturer_oreca                     -0.077053       0.097153    0.027948
# manufacturer_porsche                   -0.047621      -0.079403   -0.031123
# manufacturer_rebellion                 -0.065291      -0.001932   -0.005722
# manufacturer_riley                     -0.002658      -0.001103    0.018624
# manufacturer_srt                       -0.001708      -0.019112    0.007731
# manufacturer_strakka                   -0.002336       0.003369   -0.001024
# manufacturer_toyota                    -0.199422       0.045728   -0.000292
# manufacturer_zytek                     -0.014855      -0.015755    0.006841
# team_encoded                           -0.410271      -0.209563   -0.043160
# manufacturer_encoded                   -0.448231      -0.081807   -0.007337
#
#                                              kph  top_speed     round  \
# number                                  0.088066   0.141804 -0.109567
# driver_number                           0.145308   0.191579 -0.086514
# lap_number                              0.288588   0.298276 -0.029522
# kph                                     1.000000   0.707307 -0.258570
# top_speed                               0.707307   1.000000 -0.187140
# round                                  -0.258570  -0.187140  1.000000
# lap_time_s                              0.425502   0.481292 -0.178759
# driver_stint_no                         0.442090   0.429330 -0.111561
# team_stint_no                           0.480809   0.477747 -0.111290
# position                               -0.099142  -0.161764 -0.015114
# season_start                            0.166412   0.304764 -0.174629
# circuit_autodromo_hermanos_rodriguez   -0.151866  -0.056196  0.050864
# circuit_autodromo_nazionale_di_monza    0.093032   0.045548 -0.085031
# circuit_bahrain_international_circuit  -0.248966  -0.328104  0.415324
# circuit_circuit_of_the_americas        -0.211570  -0.183630  0.082351
# circuit_fuji_speedway                  -0.173556  -0.112852  0.132354
# circuit_interlagos                     -0.051802  -0.074725  0.242744
# circuit_le_mans                         0.667724   0.633047 -0.145828
# circuit_nurburgring                    -0.146849  -0.082933 -0.012600
# circuit_sebring                        -0.028878  -0.112115 -0.190759
# circuit_shanghai_international_circuit -0.243632  -0.037943  0.284401
# circuit_silverstone                    -0.057071  -0.227182 -0.284682
# circuit_spa_francorchamps              -0.009455  -0.078860 -0.290242
# manufacturer_aston_martin              -0.156604  -0.186768  0.022572
# manufacturer_audi                       0.076673   0.017786  0.042135
# manufacturer_aurus                      0.026641   0.038372  0.016778
# manufacturer_bmw                       -0.013364  -0.035047  0.017203
# manufacturer_br01                      -0.011571  -0.005196  0.015564
# manufacturer_br_engineering             0.036038   0.063240  0.015018
# manufacturer_chevrolet                 -0.017598  -0.048759 -0.019635
# manufacturer_clm                       -0.033411   0.006271  0.032663
# manufacturer_dallara                    0.033295   0.055724  0.008388
# manufacturer_dome                       0.012237  -0.012489 -0.051709
# manufacturer_enso                       0.001824   0.016840 -0.014130
# manufacturer_ferrari                   -0.157413  -0.218073  0.007518
# manufacturer_ford                      -0.050980  -0.055145  0.031990
# manufacturer_gibson                    -0.013395  -0.015660 -0.001071
# manufacturer_ginetta                   -0.006233   0.035810 -0.044953
# manufacturer_glickenhaus                0.162066   0.236859 -0.115583
# manufacturer_hpd                       -0.001551  -0.017331 -0.018558
# manufacturer_hpd_(honda)               -0.008737  -0.020258  0.002593
# manufacturer_ligier                     0.021554   0.032398 -0.005760
# manufacturer_lola                      -0.019666  -0.050849  0.003510
# manufacturer_morgan                    -0.018407  -0.037935 -0.011737
# manufacturer_nissan                     0.031141   0.033271 -0.017887
# manufacturer_norma                     -0.000378  -0.005635 -0.012889
# manufacturer_oak                       -0.006115  -0.001032  0.013081
# manufacturer_oreca                      0.040219   0.089198  0.007088
# manufacturer_porsche                   -0.102426  -0.141320  0.084247
# manufacturer_rebellion                  0.035693   0.096602  0.006929
# manufacturer_riley                      0.018622   0.019191 -0.008112
# manufacturer_srt                        0.010055   0.004876 -0.008673
# manufacturer_strakka                   -0.007493  -0.006142 -0.012707
# manufacturer_toyota                     0.136501   0.163972 -0.035473
# manufacturer_zytek                      0.008149  -0.030329 -0.021330
# team_encoded                            0.019089  -0.003058  0.136119
# manufacturer_encoded                    0.030169   0.021355  0.071299
#
#                                         lap_time_s  driver_stint_no  \
# number                                    0.140103         0.079765
# driver_number                             0.132936         0.104909
# lap_number                                0.326427         0.790305
# kph                                       0.425502         0.442090
# top_speed                                 0.481292         0.429330
# round                                    -0.178759        -0.111561
# lap_time_s                                1.000000         0.576227
# driver_stint_no                           0.576227         1.000000
# team_stint_no                             0.624816         0.924333
# position                                  0.413355         0.139854
# season_start                              0.157219         0.127318
# circuit_autodromo_hermanos_rodriguez     -0.123125        -0.063588
# circuit_autodromo_nazionale_di_monza     -0.131609        -0.072410
# circuit_bahrain_international_circuit    -0.230523        -0.156208
# circuit_circuit_of_the_americas          -0.125902        -0.125464
# circuit_fuji_speedway                    -0.275407        -0.132199
# circuit_interlagos                       -0.234681        -0.104597
# circuit_le_mans                           0.928795         0.628174
# circuit_nurburgring                      -0.106361        -0.079399
# circuit_sebring                          -0.118400        -0.028335
# circuit_shanghai_international_circuit   -0.141761        -0.129013
# circuit_silverstone                      -0.157048        -0.127283
# circuit_spa_francorchamps                -0.093566        -0.151653
# manufacturer_aston_martin                 0.006711        -0.050737
# manufacturer_audi                        -0.110522        -0.052930
# manufacturer_aurus                        0.029631         0.032922
# manufacturer_bmw                          0.022273        -0.004140
# manufacturer_br01                         0.009418         0.024356
# manufacturer_br_engineering               0.001149         0.008590
# manufacturer_chevrolet                    0.097361         0.027588
# manufacturer_clm                         -0.028089        -0.012384
# manufacturer_dallara                      0.037137         0.049018
# manufacturer_dome                        -0.001056         0.008022
# manufacturer_enso                        -0.012298        -0.017815
# manufacturer_ferrari                      0.103397         0.001842
# manufacturer_ford                         0.050460         0.006688
# manufacturer_gibson                       0.007416         0.008646
# manufacturer_ginetta                     -0.031066        -0.012926
# manufacturer_glickenhaus                  0.102276         0.082451
# manufacturer_hpd                         -0.008172        -0.005441
# manufacturer_hpd_(honda)                 -0.027220         0.003676
# manufacturer_ligier                       0.078890         0.073690
# manufacturer_lola                        -0.046032        -0.004914
# manufacturer_morgan                       0.008925         0.013469
# manufacturer_nissan                       0.044790         0.026394
# manufacturer_norma                        0.025993         0.020082
# manufacturer_oak                         -0.007323        -0.010399
# manufacturer_oreca                        0.039002         0.102753
# manufacturer_porsche                     -0.034811        -0.078526
# manufacturer_rebellion                   -0.007181         0.016105
# manufacturer_riley                        0.017757         0.035231
# manufacturer_srt                          0.023651         0.015043
# manufacturer_strakka                     -0.001118        -0.000306
# manufacturer_toyota                      -0.128800        -0.055455
# manufacturer_zytek                        0.018824         0.022442
# team_encoded                             -0.110670        -0.001793
# manufacturer_encoded                     -0.031347         0.066417
#
#                                         team_stint_no  position  ...  \
# number                                       0.090010  0.073136  ...
# driver_number                                0.136053  0.050297  ...
# lap_number                                   0.855867  0.038259  ...
# kph                                          0.480809 -0.099142  ...
# top_speed                                    0.477747 -0.161764  ...
# round                                       -0.111290 -0.015114  ...
# lap_time_s                                   0.624816  0.413355  ...
# driver_stint_no                              0.924333  0.139854  ...
# team_stint_no                                1.000000  0.152739  ...
# position                                     0.152739  1.000000  ...
# season_start                                 0.145315  0.041188  ...
# circuit_autodromo_hermanos_rodriguez        -0.070327 -0.001489  ...
# circuit_autodromo_nazionale_di_monza        -0.075632 -0.031846  ...
# circuit_bahrain_international_circuit       -0.162604 -0.097919  ...
# circuit_circuit_of_the_americas             -0.130431 -0.052104  ...
# circuit_fuji_speedway                       -0.142253 -0.061693  ...
# circuit_interlagos                          -0.105712 -0.109542  ...
# circuit_le_mans                              0.682669  0.312264  ...
# circuit_nurburgring                         -0.083370  0.010340  ...
# circuit_sebring                             -0.091511 -0.047125  ...
# circuit_shanghai_international_circuit      -0.133623 -0.068285  ...
# circuit_silverstone                         -0.136002 -0.023801  ...
# circuit_spa_francorchamps                   -0.155085 -0.061607  ...
# manufacturer_aston_martin                   -0.054989  0.212083  ...
# manufacturer_audi                           -0.047919 -0.249631  ...
# manufacturer_aurus                           0.031814 -0.006319  ...
# manufacturer_bmw                            -0.009675  0.067515  ...
# manufacturer_br01                            0.023175  0.022734  ...
# manufacturer_br_engineering                  0.002489 -0.025345  ...
# manufacturer_chevrolet                       0.033969  0.170097  ...
# manufacturer_clm                            -0.024445  0.025565  ...
# manufacturer_dallara                         0.051743  0.022650  ...
# manufacturer_dome                            0.002508  0.006276  ...
# manufacturer_enso                           -0.026211 -0.005830  ...
# manufacturer_ferrari                        -0.008633  0.395947  ...
# manufacturer_ford                            0.004489  0.121725  ...
# manufacturer_gibson                          0.002656  0.001355  ...
# manufacturer_ginetta                        -0.010495 -0.010272  ...
# manufacturer_glickenhaus                     0.095630 -0.095102  ...
# manufacturer_hpd                            -0.004193  0.001933  ...
# manufacturer_hpd_(honda)                    -0.003869 -0.034113  ...
# manufacturer_ligier                          0.078497  0.052972  ...
# manufacturer_lola                           -0.015376 -0.025764  ...
# manufacturer_morgan                          0.008500  0.008000  ...
# manufacturer_nissan                          0.024227  0.066892  ...
# manufacturer_norma                           0.013121  0.034859  ...
# manufacturer_oak                            -0.013209 -0.003339  ...
# manufacturer_oreca                           0.117069 -0.012583  ...
# manufacturer_porsche                        -0.077494  0.130933  ...
# manufacturer_rebellion                       0.014333 -0.076501  ...
# manufacturer_riley                           0.033923  0.041337  ...
# manufacturer_srt                             0.009683  0.026797  ...
# manufacturer_strakka                        -0.004193  0.000881  ...
# manufacturer_toyota                         -0.048085 -0.396003  ...
# manufacturer_zytek                           0.019776  0.006036  ...
# team_encoded                                -0.001639 -0.187445  ...
# manufacturer_encoded                         0.072283 -0.094880  ...
#
#                                         manufacturer_oreca  \
# number                                           -0.077053
# driver_number                                     0.097153
# lap_number                                        0.027948
# kph                                               0.040219
# top_speed                                         0.089198
# round                                             0.007088
# lap_time_s                                        0.039002
# driver_stint_no                                   0.102753
# team_stint_no                                     0.117069
# position                                         -0.012583
# season_start                                      0.122548
# circuit_autodromo_hermanos_rodriguez              0.015275
# circuit_autodromo_nazionale_di_monza              0.006280
# circuit_bahrain_international_circuit             0.010394
# circuit_circuit_of_the_americas                  -0.018047
# circuit_fuji_speedway                            -0.019330
# circuit_interlagos                               -0.043228
# circuit_le_mans                                   0.047318
# circuit_nurburgring                               0.002943
# circuit_sebring                                   0.007837
# circuit_shanghai_international_circuit           -0.018518
# circuit_silverstone                              -0.016763
# circuit_spa_francorchamps                        -0.014189
# manufacturer_aston_martin                        -0.082872
# manufacturer_audi                                -0.101319
# manufacturer_aurus                               -0.012561
# manufacturer_bmw                                 -0.021945
# manufacturer_br01                                -0.021478
# manufacturer_br_engineering                      -0.026108
# manufacturer_chevrolet                           -0.043094
# manufacturer_clm                                 -0.024429
# manufacturer_dallara                             -0.023725
# manufacturer_dome                                -0.014776
# manufacturer_enso                                -0.016803
# manufacturer_ferrari                             -0.117283
# manufacturer_ford                                -0.046179
# manufacturer_gibson                              -0.018883
# manufacturer_ginetta                             -0.019927
# manufacturer_glickenhaus                         -0.067516
# manufacturer_hpd                                 -0.004094
# manufacturer_hpd_(honda)                         -0.030612
# manufacturer_ligier                              -0.052991
# manufacturer_lola                                -0.033951
# manufacturer_morgan                              -0.030219
# manufacturer_nissan                              -0.010681
# manufacturer_norma                               -0.006343
# manufacturer_oak                                 -0.013956
# manufacturer_oreca                                1.000000
# manufacturer_porsche                             -0.149692
# manufacturer_rebellion                           -0.049584
# manufacturer_riley                               -0.004844
# manufacturer_srt                                 -0.005179
# manufacturer_strakka                             -0.004094
# manufacturer_toyota                              -0.149608
# manufacturer_zytek                               -0.024568
# team_encoded                                      0.447162
# manufacturer_encoded                              0.601493
#
#                                         manufacturer_porsche  \
# number                                             -0.047621
# driver_number                                      -0.079403
# lap_number                                         -0.031123
# kph                                                -0.102426
# top_speed                                          -0.141320
# round                                               0.084247
# lap_time_s                                         -0.034811
# driver_stint_no                                    -0.078526
# team_stint_no                                      -0.077494
# position                                            0.130933
# season_start                                       -0.145057
# circuit_autodromo_hermanos_rodriguez                0.017138
# circuit_autodromo_nazionale_di_monza               -0.048490
# circuit_bahrain_international_circuit               0.006604
# circuit_circuit_of_the_americas                     0.047803
# circuit_fuji_speedway                               0.041557
# circuit_interlagos                                  0.053270
# circuit_le_mans                                    -0.051989
# circuit_nurburgring                                 0.023763
# circuit_sebring                                    -0.045647
# circuit_shanghai_international_circuit              0.042290
# circuit_silverstone                                 0.019459
# circuit_spa_francorchamps                          -0.013310
# manufacturer_aston_martin                          -0.123370
# manufacturer_audi                                  -0.150831
# manufacturer_aurus                                 -0.018699
# manufacturer_bmw                                   -0.032670
# manufacturer_br01                                  -0.031974
# manufacturer_br_engineering                        -0.038867
# manufacturer_chevrolet                             -0.064152
# manufacturer_clm                                   -0.036367
# manufacturer_dallara                               -0.035319
# manufacturer_dome                                  -0.021997
# manufacturer_enso                                  -0.025014
# manufacturer_ferrari                               -0.174596
# manufacturer_ford                                  -0.068745
# manufacturer_gibson                                -0.028110
# manufacturer_ginetta                               -0.029664
# manufacturer_glickenhaus                           -0.100509
# manufacturer_hpd                                   -0.006095
# manufacturer_hpd_(honda)                           -0.045571
# manufacturer_ligier                                -0.078886
# manufacturer_lola                                  -0.050542
# manufacturer_morgan                                -0.044987
# manufacturer_nissan                                -0.015901
# manufacturer_norma                                 -0.009443
# manufacturer_oak                                   -0.020777
# manufacturer_oreca                                 -0.149692
# manufacturer_porsche                                1.000000
# manufacturer_rebellion                             -0.073814
# manufacturer_riley                                 -0.007212
# manufacturer_srt                                   -0.007710
# manufacturer_strakka                               -0.006095
# manufacturer_toyota                                -0.222718
# manufacturer_zytek                                 -0.036573
# team_encoded                                       -0.012533
# manufacturer_encoded                               -0.039472
#
#                                         manufacturer_rebellion  \
# number                                               -0.065291
# driver_number                                        -0.001932
# lap_number                                           -0.005722
# kph                                                   0.035693
# top_speed                                             0.096602
# round                                                 0.006929
# lap_time_s                                           -0.007181
# driver_stint_no                                       0.016105
# team_stint_no                                         0.014333
# position                                             -0.076501
# season_start                                         -0.023938
# circuit_autodromo_hermanos_rodriguez                  0.001786
# circuit_autodromo_nazionale_di_monza                 -0.025039
# circuit_bahrain_international_circuit                -0.023147
# circuit_circuit_of_the_americas                       0.028252
# circuit_fuji_speedway                                 0.004439
# circuit_interlagos                                   -0.021285
# circuit_le_mans                                       0.000314
# circuit_nurburgring                                   0.016224
# circuit_sebring                                      -0.009944
# circuit_shanghai_international_circuit                0.002457
# circuit_silverstone                                   0.036506
# circuit_spa_francorchamps                             0.008951
# manufacturer_aston_martin                            -0.040865
# manufacturer_audi                                    -0.049961
# manufacturer_aurus                                   -0.006194
# manufacturer_bmw                                     -0.010821
# manufacturer_br01                                    -0.010591
# manufacturer_br_engineering                          -0.012874
# manufacturer_chevrolet                               -0.021250
# manufacturer_clm                                     -0.012046
# manufacturer_dallara                                 -0.011699
# manufacturer_dome                                    -0.007286
# manufacturer_enso                                    -0.008286
# manufacturer_ferrari                                 -0.057833
# manufacturer_ford                                    -0.022771
# manufacturer_gibson                                  -0.009311
# manufacturer_ginetta                                 -0.009826
# manufacturer_glickenhaus                             -0.033293
# manufacturer_hpd                                     -0.002019
# manufacturer_hpd_(honda)                             -0.015095
# manufacturer_ligier                                  -0.026130
# manufacturer_lola                                    -0.016742
# manufacturer_morgan                                  -0.014901
# manufacturer_nissan                                  -0.005267
# manufacturer_norma                                   -0.003128
# manufacturer_oak                                     -0.006882
# manufacturer_oreca                                   -0.049584
# manufacturer_porsche                                 -0.073814
# manufacturer_rebellion                                1.000000
# manufacturer_riley                                   -0.002389
# manufacturer_srt                                     -0.002554
# manufacturer_strakka                                 -0.002019
# manufacturer_toyota                                  -0.073773
# manufacturer_zytek                                   -0.012115
# team_encoded                                          0.053180
# manufacturer_encoded                                  0.059503
#
#                                         manufacturer_riley  manufacturer_srt  \
# number                                           -0.002658         -0.001708
# driver_number                                    -0.001103         -0.019112
# lap_number                                        0.018624          0.007731
# kph                                               0.018622          0.010055
# top_speed                                         0.019191          0.004876
# round                                            -0.008112         -0.008673
# lap_time_s                                        0.017757          0.023651
# driver_stint_no                                   0.035231          0.015043
# team_stint_no                                     0.033923          0.009683
# position                                          0.041337          0.026797
# season_start                                      0.000671         -0.009522
# circuit_autodromo_hermanos_rodriguez             -0.002070         -0.002213
# circuit_autodromo_nazionale_di_monza             -0.002446         -0.002615
# circuit_bahrain_international_circuit            -0.005574         -0.005959
# circuit_circuit_of_the_americas                  -0.003654         -0.003906
# circuit_fuji_speedway                            -0.004431         -0.004737
# circuit_interlagos                               -0.003237         -0.003461
# circuit_le_mans                                   0.021834          0.023342
# circuit_nurburgring                              -0.002473         -0.002644
# circuit_sebring                                  -0.003203         -0.003424
# circuit_shanghai_international_circuit           -0.004059         -0.004339
# circuit_silverstone                              -0.004102         -0.004385
# circuit_spa_francorchamps                        -0.005133         -0.005487
# manufacturer_aston_martin                        -0.003993         -0.004268
# manufacturer_audi                                -0.004881         -0.005218
# manufacturer_aurus                               -0.000605         -0.000647
# manufacturer_bmw                                 -0.001057         -0.001130
# manufacturer_br01                                -0.001035         -0.001106
# manufacturer_br_engineering                      -0.001258         -0.001345
# manufacturer_chevrolet                           -0.002076         -0.002219
# manufacturer_clm                                 -0.001177         -0.001258
# manufacturer_dallara                             -0.001143         -0.001222
# manufacturer_dome                                -0.000712         -0.000761
# manufacturer_enso                                -0.000810         -0.000865
# manufacturer_ferrari                             -0.005650         -0.006041
# manufacturer_ford                                -0.002225         -0.002378
# manufacturer_gibson                              -0.000910         -0.000973
# manufacturer_ginetta                             -0.000960         -0.001026
# manufacturer_glickenhaus                         -0.003253         -0.003477
# manufacturer_hpd                                 -0.000197         -0.000211
# manufacturer_hpd_(honda)                         -0.001475         -0.001577
# manufacturer_ligier                              -0.002553         -0.002729
# manufacturer_lola                                -0.001636         -0.001749
# manufacturer_morgan                              -0.001456         -0.001556
# manufacturer_nissan                              -0.000515         -0.000550
# manufacturer_norma                               -0.000306         -0.000327
# manufacturer_oak                                 -0.000672         -0.000719
# manufacturer_oreca                               -0.004844         -0.005179
# manufacturer_porsche                             -0.007212         -0.007710
# manufacturer_rebellion                           -0.002389         -0.002554
# manufacturer_riley                                1.000000         -0.000250
# manufacturer_srt                                 -0.000250          1.000000
# manufacturer_strakka                             -0.000197         -0.000211
# manufacturer_toyota                              -0.007208         -0.007705
# manufacturer_zytek                               -0.001184         -0.001265
# team_encoded                                     -0.002132         -0.003456
# manufacturer_encoded                              0.006224         -0.004275
#
#                                         manufacturer_strakka  \
# number                                             -0.002336
# driver_number                                       0.003369
# lap_number                                         -0.001024
# kph                                                -0.007493
# top_speed                                          -0.006142
# round                                              -0.012707
# lap_time_s                                         -0.001118
# driver_stint_no                                    -0.000306
# team_stint_no                                      -0.004193
# position                                            0.000881
# season_start                                       -0.007528
# circuit_autodromo_hermanos_rodriguez               -0.001750
# circuit_autodromo_nazionale_di_monza               -0.002067
# circuit_bahrain_international_circuit              -0.004711
# circuit_circuit_of_the_americas                    -0.003088
# circuit_fuji_speedway                              -0.003745
# circuit_interlagos                                 -0.002736
# circuit_le_mans                                    -0.009034
# circuit_nurburgring                                -0.002090
# circuit_sebring                                    -0.002707
# circuit_shanghai_international_circuit             -0.003430
# circuit_silverstone                                -0.003466
# circuit_spa_francorchamps                           0.038428
# manufacturer_aston_martin                          -0.003374
# manufacturer_audi                                  -0.004125
# manufacturer_aurus                                 -0.000511
# manufacturer_bmw                                   -0.000894
# manufacturer_br01                                  -0.000874
# manufacturer_br_engineering                        -0.001063
# manufacturer_chevrolet                             -0.001755
# manufacturer_clm                                   -0.000995
# manufacturer_dallara                               -0.000966
# manufacturer_dome                                  -0.000602
# manufacturer_enso                                  -0.000684
# manufacturer_ferrari                               -0.004775
# manufacturer_ford                                  -0.001880
# manufacturer_gibson                                -0.000769
# manufacturer_ginetta                               -0.000811
# manufacturer_glickenhaus                           -0.002749
# manufacturer_hpd                                   -0.000167
# manufacturer_hpd_(honda)                           -0.001246
# manufacturer_ligier                                -0.002158
# manufacturer_lola                                  -0.001382
# manufacturer_morgan                                -0.001230
# manufacturer_nissan                                -0.000435
# manufacturer_norma                                 -0.000258
# manufacturer_oak                                   -0.000568
# manufacturer_oreca                                 -0.004094
# manufacturer_porsche                               -0.006095
# manufacturer_rebellion                             -0.002019
# manufacturer_riley                                 -0.000197
# manufacturer_srt                                   -0.000211
# manufacturer_strakka                                1.000000
# manufacturer_toyota                                -0.006091
# manufacturer_zytek                                 -0.001000
# team_encoded                                        0.012034
# manufacturer_encoded                                0.004483
#
#                                         manufacturer_toyota  \
# number                                            -0.199422
# driver_number                                      0.045728
# lap_number                                        -0.000292
# kph                                                0.136501
# top_speed                                          0.163972
# round                                             -0.035473
# lap_time_s                                        -0.128800
# driver_stint_no                                   -0.055455
# team_stint_no                                     -0.048085
# position                                          -0.396003
# season_start                                       0.142361
# circuit_autodromo_hermanos_rodriguez              -0.028235
# circuit_autodromo_nazionale_di_monza               0.045617
# circuit_bahrain_international_circuit              0.060681
# circuit_circuit_of_the_americas                   -0.015081
# circuit_fuji_speedway                             -0.005118
# circuit_interlagos                                 0.014617
# circuit_le_mans                                   -0.069727
# circuit_nurburgring                               -0.029824
# circuit_sebring                                   -0.006000
# circuit_shanghai_international_circuit            -0.009094
# circuit_silverstone                               -0.014221
# circuit_spa_francorchamps                          0.017159
# manufacturer_aston_martin                         -0.123301
# manufacturer_audi                                 -0.150747
# manufacturer_aurus                                -0.018689
# manufacturer_bmw                                  -0.032651
# manufacturer_br01                                 -0.031956
# manufacturer_br_engineering                       -0.038845
# manufacturer_chevrolet                            -0.064116
# manufacturer_clm                                  -0.036347
# manufacturer_dallara                              -0.035299
# manufacturer_dome                                 -0.021985
# manufacturer_enso                                 -0.025000
# manufacturer_ferrari                              -0.174498
# manufacturer_ford                                 -0.068706
# manufacturer_gibson                               -0.028094
# manufacturer_ginetta                              -0.029648
# manufacturer_glickenhaus                          -0.100453
# manufacturer_hpd                                  -0.006091
# manufacturer_hpd_(honda)                          -0.045546
# manufacturer_ligier                               -0.078842
# manufacturer_lola                                 -0.050514
# manufacturer_morgan                               -0.044961
# manufacturer_nissan                               -0.015892
# manufacturer_norma                                -0.009438
# manufacturer_oak                                  -0.020765
# manufacturer_oreca                                -0.149608
# manufacturer_porsche                              -0.222718
# manufacturer_rebellion                            -0.073773
# manufacturer_riley                                -0.007208
# manufacturer_srt                                  -0.007705
# manufacturer_strakka                              -0.006091
# manufacturer_toyota                                1.000000
# manufacturer_zytek                                -0.036553
# team_encoded                                      -0.156845
# manufacturer_encoded                              -0.189880
#
#                                         manufacturer_zytek  team_encoded  \
# number                                           -0.014855     -0.410271
# driver_number                                    -0.015755     -0.209563
# lap_number                                        0.006841     -0.043160
# kph                                               0.008149      0.019089
# top_speed                                        -0.030329     -0.003058
# round                                            -0.021330      0.136119
# lap_time_s                                        0.018824     -0.110670
# driver_stint_no                                   0.022442     -0.001793
# team_stint_no                                     0.019776     -0.001639
# position                                          0.006036     -0.187445
# season_start                                     -0.103379     -0.501154
# circuit_autodromo_hermanos_rodriguez             -0.010499      0.017670
# circuit_autodromo_nazionale_di_monza             -0.012406     -0.148643
# circuit_bahrain_international_circuit            -0.006764     -0.026664
# circuit_circuit_of_the_americas                  -0.012789      0.063985
# circuit_fuji_speedway                            -0.009529      0.095295
# circuit_interlagos                                0.009197      0.115964
# circuit_le_mans                                   0.016741     -0.076421
# circuit_nurburgring                              -0.012541      0.032603
# circuit_sebring                                   0.013932     -0.076344
# circuit_shanghai_international_circuit           -0.010119      0.093304
# circuit_silverstone                               0.018952      0.062148
# circuit_spa_francorchamps                         0.002643      0.010098
# manufacturer_aston_martin                        -0.020248     -0.159921
# manufacturer_audi                                -0.024755      0.236235
# manufacturer_aurus                               -0.003069      0.065063
# manufacturer_bmw                                 -0.005362     -0.021530
# manufacturer_br01                                -0.005248      0.056893
# manufacturer_br_engineering                      -0.006379      0.072908
# manufacturer_chevrolet                           -0.010529     -0.039910
# manufacturer_clm                                 -0.005969      0.026189
# manufacturer_dallara                             -0.005797      0.074882
# manufacturer_dome                                -0.003610      0.021276
# manufacturer_enso                                -0.004105      0.018022
# manufacturer_ferrari                             -0.028655     -0.208712
# manufacturer_ford                                -0.011283     -0.044903
# manufacturer_gibson                              -0.004613      0.066381
# manufacturer_ginetta                             -0.004869      0.019636
# manufacturer_glickenhaus                         -0.016496     -0.343538
# manufacturer_hpd                                 -0.001000      0.021206
# manufacturer_hpd_(honda)                         -0.007479      0.079265
# manufacturer_ligier                              -0.012947      0.218366
# manufacturer_lola                                -0.008295      0.076602
# manufacturer_morgan                              -0.007383      0.105662
# manufacturer_nissan                              -0.002610      0.009286
# manufacturer_norma                               -0.001550      0.010387
# manufacturer_oak                                 -0.003410      0.058021
# manufacturer_oreca                               -0.024568      0.447162
# manufacturer_porsche                             -0.036573     -0.012533
# manufacturer_rebellion                           -0.012115      0.053180
# manufacturer_riley                               -0.001184     -0.002132
# manufacturer_srt                                 -0.001265     -0.003456
# manufacturer_strakka                             -0.001000      0.012034
# manufacturer_toyota                              -0.036553     -0.156845
# manufacturer_zytek                                1.000000      0.118098
# team_encoded                                      0.118098      1.000000
# manufacturer_encoded                              0.146959      0.761362
#
#                                         manufacturer_encoded
# number                                             -0.448231
# driver_number                                      -0.081807
# lap_number                                         -0.007337
# kph                                                 0.030169
# top_speed                                           0.021355
# round                                               0.071299
# lap_time_s                                         -0.031347
# driver_stint_no                                     0.066417
# team_stint_no                                       0.072283
# position                                           -0.094880
# season_start                                       -0.272596
# circuit_autodromo_hermanos_rodriguez                0.019318
# circuit_autodromo_nazionale_di_monza               -0.106240
# circuit_bahrain_international_circuit              -0.005879
# circuit_circuit_of_the_americas                     0.019849
# circuit_fuji_speedway                               0.040147
# circuit_interlagos                                  0.036055
# circuit_le_mans                                    -0.012765
# circuit_nurburgring                                 0.022978
# circuit_sebring                                    -0.027778
# circuit_shanghai_international_circuit              0.037095
# circuit_silverstone                                 0.021093
# circuit_spa_francorchamps                           0.016831
# manufacturer_aston_martin                          -0.192383
# manufacturer_audi                                   0.270384
# manufacturer_aurus                                  0.070410
# manufacturer_bmw                                   -0.026133
# manufacturer_br01                                   0.128476
# manufacturer_br_engineering                         0.031331
# manufacturer_chevrolet                             -0.096582
# manufacturer_clm                                    0.029316
# manufacturer_dallara                                0.141919
# manufacturer_dome                                   0.032589
# manufacturer_enso                                   0.020131
# manufacturer_ferrari                               -0.297033
# manufacturer_ford                                  -0.056763
# manufacturer_gibson                                 0.112931
# manufacturer_ginetta                                0.023912
# manufacturer_glickenhaus                           -0.403242
# manufacturer_hpd                                    0.004483
# manufacturer_hpd_(honda)                            0.066857
# manufacturer_ligier                                 0.316979
# manufacturer_lola                                   0.095654
# manufacturer_morgan                                 0.180765
# manufacturer_nissan                                 0.010292
# manufacturer_norma                                  0.011784
# manufacturer_oak                                    0.016383
# manufacturer_oreca                                  0.601493
# manufacturer_porsche                               -0.039472
# manufacturer_rebellion                              0.059503
# manufacturer_riley                                  0.006224
# manufacturer_srt                                   -0.004275
# manufacturer_strakka                                0.004483
# manufacturer_toyota                                -0.189880
# manufacturer_zytek                                  0.146959
# team_encoded                                        0.761362
# manufacturer_encoded                                1.000000
#
# [57 rows x 57 columns]

# %%
x=df1.drop('class',axis=1).values
y=df1['class'].values
x
# Out:
# array([[8.00000000e+00, 3.00000000e+00, 8.80000000e+01, ...,
#         0.00000000e+00, 8.29427470e-01, 1.96722812e+00],
#        [3.60000000e+01, 2.00000000e+00, 1.00000000e+02, ...,
#         0.00000000e+00, 5.55111512e-16, 1.02021478e+00],
#        [7.08000000e+02, 1.00000000e+00, 7.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [2.70000000e+01, 0.00000000e+00, 2.81000000e+02, ...,
#         0.00000000e+00, 3.81034483e+00, 4.99999897e+00],
#        [2.70000000e+01, 1.00000000e+00, 9.00000000e+00, ...,
#         0.00000000e+00, 3.81034483e+00, 5.00000000e+00],
#        [2.90000000e+01, 3.00000000e+00, 8.20000000e+01, ...,
#         0.00000000e+00, 4.99999770e+00, 5.00000000e+00]],
#       shape=(30000, 57))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
print(x_train)
# Out:
# [[3.60000000e+01 2.00000000e+00 3.50000000e+01 ... 0.00000000e+00
#   0.00000000e+00 1.02021478e+00]
#  [3.60000000e+01 2.00000000e+00 2.17000000e+02 ... 0.00000000e+00
#   5.55111512e-16 1.02021478e+00]
#  [8.40000000e+01 2.00000000e+00 1.43000000e+02 ... 0.00000000e+00
#   1.16939533e+00 1.43878116e+00]
#  ...
#  [7.10000000e+01 1.00000000e+00 8.80000000e+01 ... 0.00000000e+00
#   1.71692745e+00 1.43878116e+00]
#  [8.00000000e+00 3.00000000e+00 1.19000000e+02 ... 0.00000000e+00
#   8.29427470e-01 1.96722812e+00]
#  [2.20000000e+01 3.00000000e+00 2.22000000e+02 ... 0.00000000e+00
#   4.99831229e+00 5.00000000e+00]]

# %%
unique_values = []
[unique_values.append(x) for x in y_train if x not in unique_values]
print(unique_values)
# Out:
# ['HYPERCAR', 'LMGTE Am', 'LMP2', 'LMP1', 'LMP1-H', 'LMGTE Pro']

# %%
from sklearn.preprocessing import MinMaxScaler
from joblib import dump

scale=MinMaxScaler()
scale.fit(x_train)
x_train=scale.transform(x_train)
x_test=scale.transform(x_test)
dump(scale, 'minmax_scaler.pkl')
# Out:
# ['minmax_scaler.pkl']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score,precision_score,classification_report,confusion_matrix,ConfusionMatrixDisplay

knn=KNeighborsClassifier(n_neighbors=201)
svc=SVC()
nb=BernoulliNB()
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()

models=[knn,svc,nb,dtc,rfc]
model_lst=['KNeighborsClassifier','SVC','BernoulliNB','DecisionTreeClassifier','RandomForestClassifier']

for i in range(len(model_lst)):
    
    model=models[i]
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print('\n\n')
    print("MODEL :",model_lst[i])
    print('Accuary :',accuracy_score(y_test,y_pred))
    print('Precision :',precision_score(y_test,y_pred,average='weighted'))
    print(classification_report(y_test,y_pred))
    cm=confusion_matrix(y_test,y_pred)
    cmd=ConfusionMatrixDisplay(cm,display_labels=unique_values)
    cmd.plot()
    plt.Figure(figsize=(8,8))
# Out:
# MODEL : KNeighborsClassifier
# Accuary : 0.7608888888888888
# Precision : 0.7926853140621485
#               precision    recall  f1-score   support
#
#     HYPERCAR       0.82      1.00      0.90      1559
#     LMGTE Am       0.67      0.76      0.71      1500
#    LMGTE Pro       0.73      0.54      0.62      1541
#         LMP1       0.93      0.36      0.52      1472
#       LMP1-H       0.62      0.99      0.76      1457
#         LMP2       0.99      0.92      0.95      1471
#
#     accuracy                           0.76      9000
#    macro avg       0.79      0.76      0.74      9000
# weighted avg       0.79      0.76      0.74      9000
#
#
#
#
# MODEL : SVC
# Accuary : 0.9258888888888889
# Precision : 0.9307067683228922
#               precision    recall  f1-score   support
#
#     HYPERCAR       1.00      1.00      1.00      1559
#     LMGTE Am       0.90      0.86      0.88      1500
#    LMGTE Pro       0.87      0.91      0.89      1541
#         LMP1       0.98      0.80      0.88      1472
#       LMP1-H       0.83      0.99      0.90      1457
#         LMP2       1.00      1.00      1.00      1471
#
#     accuracy                           0.93      9000
#    macro avg       0.93      0.93      0.93      9000
# weighted avg       0.93      0.93      0.93      9000
#
#
#
#
# MODEL : BernoulliNB
# Accuary : 0.7168888888888889
# Precision : 0.7340724045128605
#               precision    recall  f1-score   support
#
#     HYPERCAR       0.85      0.96      0.90      1559
#     LMGTE Am       0.52      0.65      0.57      1500
#    LMGTE Pro       0.62      0.48      0.54      1541
#         LMP1       0.86      0.55      0.67      1472
#       LMP1-H       0.60      0.75      0.67      1457
#         LMP2       0.96      0.92      0.94      1471
#
#     accuracy                           0.72      9000
#    macro avg       0.73      0.72      0.71      9000
# weighted avg       0.73      0.72      0.71      9000
#
#
#
#
# MODEL : DecisionTreeClassifier
# Accuary : 0.9994444444444445
# Precision : 0.9994462411959177
#               precision    recall  f1-score   support
#
#     HYPERCAR       1.00      1.00      1.00      1559
#     LMGTE Am       1.00      1.00      1.00      1500
#    LMGTE Pro       1.00      1.00      1.00      1541
#         LMP1       1.00      1.00      1.00      1472
#       LMP1-H       1.00      1.00      1.00      1457
#         LMP2       1.00      1.00      1.00      1471
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000
#
#
#
#
# MODEL : RandomForestClassifier
# Accuary : 0.9964444444444445
# Precision : 0.9964472092087676
#               precision    recall  f1-score   support
#
#     HYPERCAR       1.00      1.00      1.00      1559
#     LMGTE Am       0.99      0.99      0.99      1500
#    LMGTE Pro       0.99      0.99      0.99      1541
#         LMP1       1.00      1.00      1.00      1472
#       LMP1-H       1.00      1.00      1.00      1457
#         LMP2       1.00      1.00      1.00      1471
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('Accuary :',accuracy_score(y_test,y_pred))
print('Precision :',precision_score(y_test,y_pred,average='weighted'))
print(classification_report(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
cmd=ConfusionMatrixDisplay(cm,display_labels=unique_values)
cmd.plot()
plt.Figure(figsize=(8,8))
# Out:
# Accuary : 0.9964444444444445
# Precision : 0.9964519138202919
#               precision    recall  f1-score   support
#
#     HYPERCAR       1.00      1.00      1.00      1559
#     LMGTE Am       0.99      0.99      0.99      1500
#    LMGTE Pro       0.99      0.99      0.99      1541
#         LMP1       1.00      1.00      1.00      1472
#       LMP1-H       1.00      1.00      1.00      1457
#         LMP2       1.00      1.00      1.00      1471
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000

# %% [markdown]
# ### Improving KNN

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_neighbors':list(range(201,502,50)),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree','brute']
}

grid_search = GridSearchCV(knn,params, cv=5, scoring='accuracy',n_jobs=-2)

grid_search.fit(x_train,y_train)
# Out:
# c:\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.74833333 0.83480952 0.73357143 0.82571429 0.72542857 0.81880952
#  0.71928571 0.81557143 0.71485714 0.81285714 0.71971429 0.81004762
#  0.72014286 0.80671429        nan 0.87785714        nan 0.87257143
#         nan 0.86709524        nan 0.86233333        nan 0.85780952
#         nan 0.85385714        nan 0.84985714 0.74833333 0.83480952
#  0.73357143 0.82571429 0.72542857 0.81880952 0.71928571 0.81557143
#  0.71485714 0.81285714 0.71971429 0.81004762 0.72014286 0.80671429
#  0.799      0.87785714 0.78838095 0.87257143 0.791      0.86709524
#  0.78680952 0.86233333 0.7852381  0.85780952 0.78304762 0.85385714
#  0.779      0.84985714 0.74833333 0.83480952 0.73357143 0.82571429
#  0.72542857 0.81880952 0.71928571 0.81557143 0.71485714 0.81285714
#  0.71971429 0.81004762 0.72014286 0.80671429 0.799      0.87785714
#  0.78838095 0.87257143 0.791      0.86709524 0.78680952 0.86233333
#  0.7852381  0.85780952 0.78304762 0.85385714 0.779      0.84985714
#  0.74833333 0.83480952 0.73357143 0.82571429 0.72542857 0.81880952
#  0.71928571 0.81557143 0.71485714 0.81285714 0.71971429 0.81004762
#  0.72014286 0.80671429        nan 0.87785714        nan 0.87257143
#         nan 0.86709524        nan 0.86233333        nan 0.85780952
#         nan 0.85385714        nan 0.84985714]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=201), n_jobs=-2,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [201, 251, 301, 351, 401, 451, 501],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'algorithm': 'auto', 'metric': 'manhattan', 'n_neighbors': 201, 'weights': 'distance'}

# %%
knn=KNeighborsClassifier(n_neighbors=101,algorithm='auto',metric='manhattan',weights='distance')
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
print('Accuary :',accuracy_score(y_test,y_pred))
print('Precision :',precision_score(y_test,y_pred,average='weighted'))
print(classification_report(y_test,y_pred))
cm=confusion_matrix(y_test,y_pred)
cmd=ConfusionMatrixDisplay(cm,display_labels=unique_values)
cmd.plot()
plt.Figure(figsize=(8,8))
# Out:
# Accuary : 0.9121111111111111
# Precision : 0.9204072348116806
#               precision    recall  f1-score   support
#
#     HYPERCAR       0.96      1.00      0.98      1559
#     LMGTE Am       0.91      0.84      0.88      1500
#    LMGTE Pro       0.86      0.92      0.89      1541
#         LMP1       0.99      0.72      0.83      1472
#       LMP1-H       0.80      1.00      0.89      1457
#         LMP2       1.00      0.99      0.99      1471
#
#     accuracy                           0.91      9000
#    macro avg       0.92      0.91      0.91      9000
# weighted avg       0.92      0.91      0.91      9000

# %%
j=df1.loc[(df1['class']=='LMGTE Am')&(df1['circuit_le_mans'])&(df1['manufacturer_porsche'])]
j=j.drop('class',axis=1)
j=j.head(1)

print(j)
# Out:
#       number  driver_number  lap_number    kph  top_speed  round  lap_time_s  \
# 5000      89              3         303  202.5      287.7      7      242.28
#
#       driver_stint_no  team_stint_no  position  ...  manufacturer_oreca  \
# 5000                9             24      45.0  ...                 0.0
#
#       manufacturer_porsche  manufacturer_rebellion  manufacturer_riley  \
# 5000                   1.0                     0.0                 0.0
#
#       manufacturer_srt  manufacturer_strakka  manufacturer_toyota  \
# 5000               0.0                   0.0                  0.0
#
#       manufacturer_zytek  team_encoded  manufacturer_encoded
# 5000                 0.0           1.0              2.387781
#
# [1 rows x 57 columns]

# %%
model=KNeighborsClassifier(n_neighbors=201,algorithm='auto',metric='manhattan',weights='distance')
model.fit(x_train,y_train)
y=model.predict(scale.transform(j))
y
# Out:
# array(['HYPERCAR', 'HYPERCAR', 'HYPERCAR', ..., 'HYPERCAR', 'HYPERCAR',
#        'HYPERCAR'], shape=(2052,), dtype=object)

# %%
output=pd.DataFrame({'output':y})
output['output'].value_counts()
# Out:
# output
# HYPERCAR    2052
# Name: count, dtype: int64

# %%
from joblib import dump
dump(model, "RandomForestClassifier.pkl", compress=3)
# Out:
# ['RandomForestClassifier.pkl']

# %%
df1.columns
# Out:
# Index(['number', 'driver_number', 'lap_number', 'kph', 'top_speed', 'round',
#        'lap_time_s', 'driver_stint_no', 'team_stint_no', 'position',
#        'season_start', 'class', 'circuit_autodromo_hermanos_rodriguez',
#        'circuit_autodromo_nazionale_di_monza',
#        'circuit_bahrain_international_circuit',
#        'circuit_circuit_of_the_americas', 'circuit_fuji_speedway',
#        'circuit_interlagos', 'circuit_le_mans', 'circuit_nurburgring',
#        'circuit_sebring', 'circuit_shanghai_international_circuit',
#        'circuit_silverstone', 'circuit_spa_francorchamps',
#        'manufacturer_aston_martin', 'manufacturer_audi', 'manufacturer_aurus',
#        'manufacturer_bmw', 'manufacturer_br01', 'manufacturer_br_engineering',
#        'manufacturer_chevrolet', 'manufacturer_clm', 'manufacturer_dallara',
#        'manufacturer_dome', 'manufacturer_enso', 'manufacturer_ferrari',
#        'manufacturer_ford', 'manufacturer_gibson', 'manufacturer_ginetta',
#        'manufacturer_glickenhaus', 'manufacturer_hpd',
#        'manufacturer_hpd_(honda)', 'manufacturer_ligier', 'manufacturer_lola',
#        'manufacturer_morgan', 'manufacturer_nissan', 'manufacturer_norma',
#        'manufacturer_oak', 'manufacturer_oreca', 'manufacturer_porsche',
#        'manufacturer_rebellion', 'manufacturer_riley', 'manufacturer_srt',
#        'manufacturer_strakka', 'manufacturer_toyota', 'manufacturer_zytek',
#        'team_encoded', 'manufacturer_encoded'],
#       dtype='object')
